# %% [markdown]
# # Overview

# %% [markdown]
# In this notebook we plot the figures showing the simulation results in Tootoonian et al. 2021.

# %%
# %pylab inline
import os, sys
sys.path.append(os.path.join(os.environ["SISTER_MCS"], "code"))
from importlib import reload
import pickle
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import util
import figtools as ft
import datatools as dt
logger = util.create_logger("make_figures")

# %% [markdown]
# Figures 1-4 are schematics, Figure 5 is the first data figure.

# %% [markdown]
# # Figure 5: Typical dynamics

# %%
import figfuns as ff
pa = {"linewidth":1}
ff.plot_glom1_glom2(leak=False, imc = [2,8][:1], figsize=(4.3,7), xl = (-0.01, 0.4), plot_args = pa)
# Out:
# 2021/06/28 16:54:40                  figfuns     INFO: Started plot_glom1_glom2.
# 2021/06/28 16:54:41                datatools     INFO: Read params files #500   in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread...
# 2021/06/28 16:54:42                datatools     INFO: Read params files #1000  in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread...
# 2021/06/28 16:54:42                datatools     INFO: Read params files #1500  in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread...
# 2021/06/28 16:54:44                datatools     INFO: Read 1560 params files in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread.
# 2021/06/28 16:54:44                  figfuns     INFO: Found 5 seeds for S=4 and leak_pg=False and k=3.
# 2021/06/28 16:54:44                datatools  WARNING: Could not find /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread/params245/x_input.npy.
# 2021/06/28 16:54:45                  figfuns     INFO: Plotting mitral cells in glomerulus 2.
# 2021/06/28 16:54:45                  figfuns     INFO: Plotting periglomerular cells in glomerulus 2.
# 2021/06/28 16:54:45                  figfuns     INFO: Plotting granule cells.
# 2021/06/28 16:54:46                  figfuns     INFO: Plotting RMSE.
# 2021/06/28 16:54:46                  figfuns     INFO: Finalizing figure.
# 2021/06/28 16:54:47                  figfuns     INFO: Writing glom1_glom2_S4.pdf.
# 2021/06/28 16:54:49                  figfuns     INFO: Finished plot_glom1_glom2.
# [<matplotlib.axes._subplots.AxesSubplot at 0x7f92b83901c0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f92b84d9a60>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f92b8630d90>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f9299c48850>]

# %% [markdown]
# # Figure 6: Dynamics for different sister sizes

# %%
figure(figsize=(6,8))
gs = GridSpec(5,3)
pa = {"linewidth":1}
ax1 = ff.plot_glom1_glom2(leak=False, imc = [2,8][:1], xl = (-0.01, 0.4), S = 1,  gs = [gs[i,0] for i in range(5)], plot_args = pa, label_axes = False, save_figure = False);
ax2 = ff.plot_glom1_glom2(leak=False, imc = [2,8][:1], xl = (-0.01, 0.4), S = 8,  gs = [gs[i,1] for i in range(5)], plot_args = pa, ylabels = False, label_axes = False, save_figure = False);
ax3 = ff.plot_glom1_glom2(leak=False, imc = [2,8][:1], xl = (-0.01, 0.4), S = 25, gs = [gs[i,2] for i in range(5)], plot_args = pa, ylabels = False, label_axes = False, save_figure = False);
ft.label_axes([ax1[0], ax2[0], ax3[0]], "ABC", dx=-0.025, fontsize=14, verticalalignment="top", horizontalalignment="left",fontweight="bold")
file_name = "glom1_glom2_multiple_S.pdf"
print(f"Writing {file_name}.")
savefig(file_name, bbox_inches="tight")
print(f"Done.")
# Out:
# 2021/06/28 16:54:55                  figfuns     INFO: Started plot_glom1_glom2.
# 2021/06/28 16:54:56                datatools     INFO: Read params files #500   in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread...
# 2021/06/28 16:54:56                datatools     INFO: Read params files #1000  in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread...
# 2021/06/28 16:54:57                datatools     INFO: Read params files #1500  in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread...
# 2021/06/28 16:54:59                datatools     INFO: Read 1560 params files in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread.
# 2021/06/28 16:54:59                  figfuns     INFO: Found 5 seeds for S=1 and leak_pg=False and k=3.
# 2021/06/28 16:54:59                datatools  WARNING: Could not find /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread/params5/x_input.npy.
# 2021/06/28 16:55:00                  figfuns     INFO: Plotting mitral cells in glomerulus 2.
# 2021/06/28 16:55:00                  figfuns     INFO: Plotting periglomerular cells in glomerulus 2.
# 2021/06/28 16:55:00                  figfuns     INFO: Plotting granule cells.
# 2021/06/28 16:55:01                  figfuns     INFO: Plotting RMSE.
# 2021/06/28 16:55:01                  figfuns     INFO: Finalizing figure.
# 2021/06/28 16:55:01                  figfuns     INFO: Finished plot_glom1_glom2.
# 2021/06/28 16:55:01                  figfuns     INFO: Started plot_glom1_glom2.
# 2021/06/28 16:55:01                datatools     INFO: Read params files #500   in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread...
# 2021/06/28 16:55:02                datatools     INFO: Read params files #1000  in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread...
# 2021/06/28 16:55:03                datatools     INFO: Read params files #1500  in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread...
# 2021/06/28 16:55:04                datatools     INFO: Read 1560 params files in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread.
# 2021/06/28 16:55:04                  figfuns     INFO: Found 5 seeds for S=8 and leak_pg=False and k=3.
# 2021/06/28 16:55:04                datatools  WARNING: Could not find /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread/params125/x_input.npy.
# 2021/06/28 16:55:05                  figfuns     INFO: Plotting mitral cells in glomerulus 2.
# 2021/06/28 16:55:05                  figfuns     INFO: Plotting periglomerular cells in glomerulus 2.
# 2021/06/28 16:55:05                  figfuns     INFO: Plotting granule cells.
# 2021/06/28 16:55:06                  figfuns     INFO: Plotting RMSE.
# 2021/06/28 16:55:06                  figfuns     INFO: Finalizing figure.
# 2021/06/28 16:55:07                  figfuns     INFO: Finished plot_glom1_glom2.
# 2021/06/28 16:55:07                  figfuns     INFO: Started plot_glom1_glom2.
# 2021/06/28 16:55:08                datatools     INFO: Read params files #500   in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread...
# 2021/06/28 16:55:08                datatools     INFO: Read params files #1000  in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread...
# 2021/06/28 16:55:09                datatools     INFO: Read params files #1500  in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread...
# 2021/06/28 16:55:11                datatools     INFO: Read 1560 params files in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread.
# 2021/06/28 16:55:11                  figfuns     INFO: Found 5 seeds for S=25 and leak_pg=False and k=3.
# 2021/06/28 16:55:11                datatools  WARNING: Could not find /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread/params185/x_input.npy.
# 2021/06/28 16:55:13                  figfuns     INFO: Plotting mitral cells in glomerulus 2.
# 2021/06/28 16:55:13                  figfuns     INFO: Plotting periglomerular cells in glomerulus 2.
# 2021/06/28 16:55:13                  figfuns     INFO: Plotting granule cells.
# 2021/06/28 16:55:14                  figfuns     INFO: Plotting RMSE.
# 2021/06/28 16:55:14                  figfuns     INFO: Finalizing figure.
# 2021/06/28 16:55:14                  figfuns     INFO: Finished plot_glom1_glom2.
# Writing glom1_glom2_multiple_S.pdf.
# Done.

# %% [markdown]
# # Figure 7: Linear analysis

# %%
import demo_linearization as demo_lin
force_compute = False
data = dt.load_if_exists_else_compute("demo_lin_data.p", demo_lin.load_data, force_compute = force_compute)
demo_lin.plot(data, leak=0.5, plot_approx_for_nu=False, xl = [-1/0.042,-1/0.08])
# Out:
# 2021/06/28 17:01:55                datatools     INFO: Loading from demo_lin_data.p.
# 2021/06/28 17:01:55                datatools     INFO: Done loading.
# 2021/06/28 17:01:55       demo_linearization     INFO: Started plot.
# 2021/06/28 17:01:55       demo_linearization     INFO: Plotting (name='sparse', S=25, n=20)
# 2021/06/28 17:01:55       demo_linearization     INFO: Plotting (name='dense', S=25, n=55)
# 2021/06/28 17:01:56       demo_linearization     INFO: Wrote demo_lin_leak=0.5.pdf.

# %% [markdown]
# # Figure 8: Transient response properties

# %%
import transient_response as tr
force_compute = False
data = dt.load_if_exists_else_compute("tr_data.p", tr.load_data, force_compute = force_compute)
tr.plot_transient_response(data)
# Out:
# 2021/06/28 17:02:50                datatools     INFO: Loading from tr_data.p.
# 2021/06/28 17:02:50                datatools     INFO: Done loading.
# 2021/06/28 17:02:50       transient_response     INFO: Plotting MC decay rates vs S.
# 2021/06/28 17:02:50       transient_response     INFO: Plotting square root fit to high frequency peak vs S.
# 2021/06/28 17:02:50       transient_response     INFO: Plotting linear fit to high frequency peak vs σ.
# 2021/06/28 17:02:50       transient_response     INFO: Saving as transient_response.pdf.
# 2021/06/28 17:02:50       transient_response     INFO: plot_transient_response finished.

# %% [markdown]
# # Figure 9: Effect of Leak

# %%
figure(figsize=(6,8))
gs = GridSpec(5,2)
plot_args = {"linewidth":1}
ax2 = ff.plot_glom1_glom2(leak=1,    imc = [2,8][:1], xl = (-0.01, 0.4), S = 8, gs = [gs[i,0] for i in range(5)], plot_args = plot_args, ylabels = True, label_axes = False, save_figure = False);
ax3 = ff.plot_glom1_glom2(leak=2,    imc = [2,8][:1], xl = (-0.01, 0.4), S = 8, gs = [gs[i,1] for i in range(5)], plot_args = plot_args, ylabels = False, label_axes = False, save_figure = False);
ft.label_axes([ax2[0], ax3[0]], "ABC", dx=-0.025, fontsize=14, verticalalignment="top", horizontalalignment="left",fontweight="bold")
file_name = "glom1_glom2_multiple_leak.pdf"
print(f"Writing {file_name}.")
savefig(file_name, bbox_inches="tight")
print(f"Done.")
# Out:
# 2021/06/28 17:03:02                  figfuns     INFO: Started plot_glom1_glom2.
# 2021/06/28 17:03:03                datatools     INFO: Read params files #500   in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread...
# 2021/06/28 17:03:03                datatools     INFO: Read params files #1000  in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread...
# 2021/06/28 17:03:04                datatools     INFO: Read params files #1500  in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread...
# 2021/06/28 17:03:06                datatools     INFO: Read 1560 params files in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread.
# 2021/06/28 17:03:06                  figfuns     INFO: Found 5 seeds for S=8 and leak_pg=1 and k=3.
# 2021/06/28 17:03:06                datatools  WARNING: Could not find /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread/params140/x_input.npy.
# 2021/06/28 17:03:07                  figfuns     INFO: Plotting mitral cells in glomerulus 2.
# 2021/06/28 17:03:07                  figfuns     INFO: Plotting periglomerular cells in glomerulus 2.
# 2021/06/28 17:03:07                  figfuns     INFO: Plotting granule cells.
# 2021/06/28 17:03:08                  figfuns     INFO: Plotting RMSE.
# 2021/06/28 17:03:08                  figfuns     INFO: Finalizing figure.
# 2021/06/28 17:03:09                  figfuns     INFO: Finished plot_glom1_glom2.
# 2021/06/28 17:03:09                  figfuns     INFO: Started plot_glom1_glom2.
# 2021/06/28 17:03:09                datatools     INFO: Read params files #500   in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread...
# 2021/06/28 17:03:10                datatools     INFO: Read params files #1000  in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread...
# 2021/06/28 17:03:10                datatools     INFO: Read params files #1500  in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread...
# 2021/06/28 17:03:12                datatools     INFO: Read 1560 params files in /camp/home/tootoos/working/tootoos/sister_mcs_data/sweep_conc_spread.
# 2021/06/28 17:03:12                  figfuns     INFO: Found 5 seeds for S=8 and leak_pg=2 and k=3.
# 2021/06/28 17:03:13                  figfuns     INFO: Plotting mitral cells in glomerulus 2.
# 2021/06/28 17:03:13                  figfuns     INFO: Plotting periglomerular cells in glomerulus 2.
# 2021/06/28 17:03:13                  figfuns     INFO: Plotting granule cells.
# 2021/06/28 17:03:13                  figfuns     INFO: Plotting RMSE.
# 2021/06/28 17:03:13                  figfuns     INFO: Finalizing figure.
# 2021/06/28 17:03:14                  figfuns     INFO: Finished plot_glom1_glom2.
# Writing glom1_glom2_multiple_leak.pdf.
# Done.

# %% [markdown]
# # Figure 10: Properties at convergence vs. periglomerular leak

# %%
import effect_of_leaky_pgs as eol
reload(eol)
force_compute = False
data = dt.load_if_exists_else_compute("eol_data.p", eol.load_data, force_compute = force_compute)
figure(figsize=(8,3))
gs = GridSpec(1,2)
which_plots = {"rmse_final":gs[0,0], "ratios":gs[0,1]}
ax = eol.plot_effect_of_leaky_pgs(data, subplots=which_plots, label_order = ["rmse_final", "ratios"], fig_name = "leak_rms")
# Out:
# 2021/06/28 17:04:43                datatools     INFO: Loading from eol_data.p.
# 2021/06/28 17:04:50                datatools     INFO: Done loading.
# 2021/06/28 17:04:50      effect_of_leaky_pgs     INFO: Started plot_effect_of_leaky_pgs.
# 2021/06/28 17:04:50      effect_of_leaky_pgs     INFO: Plotting sister cell ratios.
# 2021/06/28 17:04:50      effect_of_leaky_pgs     INFO: Plotting final rmse data.
# 2021/06/28 17:04:50      effect_of_leaky_pgs     INFO: Finalizing figure.
# 2021/06/28 17:04:50      effect_of_leaky_pgs     INFO: Saving as leak_rms.pdf.
# 2021/06/28 17:04:51      effect_of_leaky_pgs     INFO: Finished plot_effect_of_leaky_pgs.

# %% [markdown]
# # Figure 11: Effect of density

# %%
import effect_of_density as eod
force_compute = False
data = dt.load_if_exists_else_compute("eod_data.p", loader_fun = lambda: eod.load_data(n_max=6, t_decay=[1,1.5]), force_compute = force_compute)
eod.plot_effect_of_density(data, which_trial_low=0, ylim_decay=[-1e-7, 1e-7], xlim_decay_high = [1.5, 2], xlim_decay_low=[1,1.5])
# Out:
# 2021/06/28 17:05:27                datatools     INFO: Loading from eod_data.p.
# 2021/06/28 17:05:39                datatools     INFO: Done loading.
# 2021/06/28 17:05:39        effect_of_density     INFO: Started plot_effect_of_density.
# 2021/06/28 17:05:39        effect_of_density     INFO: Plotting high density MAP solution.
# 2021/06/28 17:05:39        effect_of_density     INFO: Plotting recovered vs. true density.
# 2021/06/28 17:05:39        effect_of_density     INFO: Plotting time course of recovery.
# 2021/06/28 17:05:39        effect_of_density     INFO: Finalizing figure.
# 2021/06/28 17:05:40        effect_of_density     INFO: Saving as effect_of_density.pdf.
# 2021/06/28 17:05:41        effect_of_density     INFO: Finished plot_effect_of_density.

# %% [markdown]
# # Figure 12: Effect of system size

# %%
import effect_of_size as eosz
force_compute = False
data = dt.load_if_exists_else_compute("eosz_data.p", eosz.load_data, force_compute = force_compute)
eosz.plot_effect_of_size(data, glom_target = 0.2, xl = (-0.025,0.3))
# Out:
# 2021/06/28 17:06:07                datatools     INFO: Loading from eosz_data.p.
# 2021/06/28 17:06:11                datatools     INFO: Done loading.
# 2021/06/28 17:06:11           effect_of_size     INFO: Started plot_effect_of_size.
# 2021/06/28 17:06:11           effect_of_size     INFO: Glomeruli whose final activity is closest to 0.2: {(100, 1200, 3): 70, (100, 4800, 3): 11, (200, 1200, 3): 150, (200, 4800, 3): 148}.
# 2021/06/28 17:06:11           effect_of_size     INFO:   Plotting RMSE for 5 trials.
# 2021/06/28 17:06:11           effect_of_size     INFO:   Plotting RMSE for 5 trials.
# 2021/06/28 17:06:12           effect_of_size     INFO:   Plotting RMSE for 5 trials.
# 2021/06/28 17:06:12           effect_of_size     INFO:   Plotting RMSE for 5 trials.
# 2021/06/28 17:06:12           effect_of_size     INFO: Finalizing figure.
# 2021/06/28 17:06:12           effect_of_size     INFO: Saving as effect_of_size.pdf.
# 2021/06/28 17:06:13           effect_of_size     INFO: Finished plot_effect_of_size.
